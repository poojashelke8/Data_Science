# %%
import numpy as np

data = np.genfromtxt(
    r"C:\Users\Shree\Desktop\Data_Science\Data_practice\Libraries\Numpy\Datasets\Outlier_Loan_dataset.csv",
    delimiter=",",
    skip_header=1,
    dtype=str
)

print(data)
# Out:
# [['U2169' 'L532233' 'Quetta' ... '45' '2024-11-26' '139275.96']
#  ['U2807' 'L516508' 'Karachi' ... '6' '2024-08-18' '61391.92']
#  ['U4536' 'L471613' 'Peshawar' ... '59' '2024-01-27' '115353.44']
#  ...
#  ['U7524' 'L232943' 'Rawalpindi' ... '14' '2022-07-20' '96334.77']
#  ['U8915' 'L673563' 'Faisalabad' ... '9' '2022-12-02' '142483.99']
#  ['U4571' 'L629875' 'Multan' ... '17' '2022-10-21' '96327.54']]
