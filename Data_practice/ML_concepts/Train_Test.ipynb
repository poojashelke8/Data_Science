# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset/carprices.csv")
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])
plt.xlabel("Mileage")
plt.ylabel("Selling Price")
# Out:
# Text(0, 0.5, 'Selling Price')

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])

# %%
x = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']

# %%
x
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
# 1. use train_test_split() from sklearn
from sklearn.model_selection import train_test_split

# %%
# random state=10 --> train data will be same
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 11    79000         7
# 19    52000         5
# 8     91000         8
# 5     59000         5
# 1     35000         3
# 13    58780         4
# 3     22500         2
# 7     72000         6
# 10    83000         7
# 17    69000         5
# 6     52000         5
# 9     67000         6
# 2     57000         5
# 18    87600         8
# 0     69000         6
# 14    82450         7

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([30891.28346127, 37913.66513427, 39103.87968508, 25758.91835328])

# %%
y_test
# Out:
# 4     31500
# 16    35500
# 15    35000
# 12    26000
# Name: Sell Price($), dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# 0.5983258428706708
